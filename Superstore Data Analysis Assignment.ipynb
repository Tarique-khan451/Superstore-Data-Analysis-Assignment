# %% [markdown]
# # Write CSV

# %%
import pandas as pd
import seaborn as sns
import matplotlib .pyplot as plt

csv_path = (r"C:\Users\CITY COMPUTER HYD\Desktop\Sample-Superstore.csv")
df.head(100)
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1        2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2        3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3        4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4        5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ..     ...             ...         ...         ...             ...
# 95      96  US-2017-109484   11/6/2017  11/12/2017  Standard Class
# 96      97  CA-2017-161018   11/9/2017  11/11/2017    Second Class
# 97      98  CA-2017-157833   6/17/2017   6/20/2017     First Class
# 98      99  CA-2016-149223    9/6/2016   9/11/2016  Standard Class
# 99     100  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
#
#    Customer ID      Customer Name      Segment        Country  \
# 0     CG-12520        Claire Gute     Consumer  United States
# ...

# %% [markdown]
# # Cleaning the Data

# %%
df.head(50)
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1        2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2        3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3        4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4        5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 5        6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 6        7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 7        8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 8        9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 9       10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 10      11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 11      12  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 12      13  CA-2017-114412   4/15/2017   4/20/2017  Standard Class
# ...

# %%
df.isnull().sum() #identify null values
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     -1.027326
# std     129.885954
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max      53.997000

# %% [markdown]
# # Outliers

# %%
sns.boxplot(x='Profit', data=df)
plt.show()

# %%
data = (df['Profit'] < (Q1 - 1.5 * IQR)) | (df['Profit'] > (Q3 + 1.5 * IQR))
print(data)
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9989    False
# 9990     True
# 9991     True
# 9992     True
# 9993     True
# Name: Profit, Length: 9994, dtype: bool

# %%
print(df["Profit"].quantile(0.50))   # 50th percentile (median)
print(df["Profit"].quantile(0.95))   # 95th percentile"
print(df["Profit"].quantile(0.75))   # 95th percentile"
# Out:
# 8.6665
# 38.08
# 29.364

# %%
import numpy as np
df['Profit'] = np.where(df['Profit'] > 54.0, 35.0,df['Profit'])

# %%
df['Profit'].describe()
# Out:
# count    9994.000000
# mean       -1.027326
# std       129.885954
# min     -6599.978000
# 25%         1.728750
# 50%         8.666500
# 75%        29.364000
# max        53.997000
# Name: Profit, dtype: float64

# %%
sns.boxplot(x='Profit', data=df)
# Out:
# <Axes: xlabel='Profit'>

# %%
print(df["Sales"].quantile(0.50))   # 50th percentile (median)
print(df["Sales"].quantile(0.95))   # 95th percentile"
print(df["Sales"].quantile(0.75))   # 95th percentile"
# Out:
# 54.489999999999995
# 956.9842450000003
# 209.94

# %%
sns.boxplot(x='Sales', data=df)
# Out:
# <Axes: xlabel='Sales'>

# %% [markdown]
# # Data Distribution

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_path = (r"C:\Users\CITY COMPUTER HYD\Desktop\Sample-Superstore.csv")
df.head(100)
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1        2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2        3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3        4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4        5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ..     ...             ...         ...         ...             ...
# 95      96  US-2017-109484   11/6/2017  11/12/2017  Standard Class
# 96      97  CA-2017-161018   11/9/2017  11/11/2017    Second Class
# 97      98  CA-2017-157833   6/17/2017   6/20/2017     First Class
# 98      99  CA-2016-149223    9/6/2016   9/11/2016  Standard Class
# 99     100  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
#
#    Customer ID      Customer Name      Segment        Country  \
# 0     CG-12520        Claire Gute     Consumer  United States
# ...

# %%
numeric_cols = df.select_dtypes(include='number').columns.tolist()
numeric_cols
# Out:
# ['Row ID', 'Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
plt.figure(figsize=(6,4))
plt.hist(df["Sales"], bins=30)
plt.title("Distribution of Sales")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df["Profit"], bins=30)
plt.title("Distribution of Profit")
plt.xlabel("Profit")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df["Quantity"])
plt.title("Distribution of Quantity")
plt.xlabel("Quantity")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df["Discount"], bins=20)
plt.title("Distribution of Discount")
plt.xlabel("Discount")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Calculation of Statistical Summary

# %%
import pandas as pd

# %%
csv_path = (r"C:\Users\CITY COMPUTER HYD\Desktop\Sample-Superstore.csv")
df.head(100)
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1        2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2        3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3        4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4        5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ..     ...             ...         ...         ...             ...
# 95      96  US-2017-109484   11/6/2017  11/12/2017  Standard Class
# 96      97  CA-2017-161018   11/9/2017  11/11/2017    Second Class
# 97      98  CA-2017-157833   6/17/2017   6/20/2017     First Class
# 98      99  CA-2016-149223    9/6/2016   9/11/2016  Standard Class
# 99     100  CA-2016-158568   8/29/2016    9/2/2016  Standard Class
#
#    Customer ID      Customer Name      Segment        Country  \
# 0     CG-12520        Claire Gute     Consumer  United States
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     -1.027326
# std     129.885954
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max      53.997000
